# %%
import pandas as pd

# %%
df = pd.read_csv('../data/clubs_with_interest_areas.csv')

# %%
df.interest_areas.value_counts()
# Out:
# interest_areas
# Sports & Fitness                                                         16
# Culture & Languages                                                      12
# Science & Research                                                       12
# Debate & Public Speaking                                                  7
# Business & Finance                                                        7
# Technology & Computing                                                    6
# Music & Performance                                                       6
# Arts & Creativity                                                         5
# Social Impact & Volunteering                                              4
# Gaming & Esports                                                          4
# Dance                                                                     4
# Dance; Culture & Languages                                                4
# ...

# %%
df.drop('description', axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop('description', axis=1, inplace= True)
#       2 df
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %%
df.to_csv('../data/clubs_with_interest_areas.csv')
